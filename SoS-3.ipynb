# %% [markdown]
# # Calculating Plama Required to Reach CGS's Level
# For figuring out how much plasma you need to steal from Turbo to max out all buildings & research

# %%
#############################################################
############## Plasma Upgrade Values Per Level ##############
#############################################################
########### DON'T CHANGE ANYTHING IN THIS SECTION ###########
#############################################################
#### You Will Input Your Data In The 2nd & 3rd Sections #####
#############################################################

# Concrete Values for Buildings:

# Headquarter Level Cost
hq1c = 132
hq2c = 158
hq3c = 238
hq4c = 280
hq5c = 335
#----
hq6c = 0
hq7c = 0
hq8c = 0
hq9c = 0
hq10c = 0

# Hero Precinct Level Cost
hp1c = 66
hp2c = 79
hp3c = 119
hp4c = 140
hp5c = 167
#----
hp6c = 0
hp7c = 0
hp8c = 0
hp9c = 0
hp10c = 0

# Plasma Barracks Level Cost
pb1c = 44
pb2c = 53
pb3c = 79
pb4c = 93
pb5c = 112
#----
pb6c = 0
pb7c = 0
pb8c = 0
pb9c = 0
pb10c = 0

# Plasma Range Level Cost
pr1c = 44
pr2c = 53
pr3c = 79
pr4c = 93
pr5c = 112
#----
pr6c = 0
pr7c = 0
pr8c = 0
pr9c = 0
pr10c = 0

# Plasma Garage Level Cost
pg1c = 44
pg2c = 53
pg3c = 79
pg4c = 93
pg5c = 112
#----
pg6c = 0
pg7c = 0
pg8c = 0
pg9c = 0
pg10c = 0

# Institute of Plasma Level Cost
ip1c = 0
ip2c = 71
ip3c = 105
ip4c = 124
ip5c = 149
#----
ip6c = 0
ip7c = 0
ip8c = 0
ip9c = 0
ip10c = 0


# Concrete Values for Research

# Infantry
Infantry_Strategic_Dispatch_0=0
Infantry_Strategic_Dispatch_1=Infantry_Strategic_Dispatch_0+8
Infantry_Strategic_Dispatch_2=Infantry_Strategic_Dispatch_1+12
Infantry_Strategic_Dispatch_3=Infantry_Strategic_Dispatch_2+20
Infantry_Strategic_Dispatch_4=Infantry_Strategic_Dispatch_3+32
Infantry_Strategic_Dispatch_5=Infantry_Strategic_Dispatch_4+51

Infantry_Powerful_Slash_0=0
Infantry_Powerful_Slash_1=Infantry_Powerful_Slash_0+20
Infantry_Powerful_Slash_2=Infantry_Powerful_Slash_1+26
Infantry_Powerful_Slash_3=Infantry_Powerful_Slash_2+36
Infantry_Powerful_Slash_4=Infantry_Powerful_Slash_3+48
Infantry_Powerful_Slash_5=Infantry_Powerful_Slash_4+64
Infantry_Powerful_Slash_6=Infantry_Powerful_Slash_5+87
Infantry_Powerful_Slash_7=Infantry_Powerful_Slash_6+116
Infantry_Powerful_Slash_8=Infantry_Powerful_Slash_7+157

Infantry_Unyielding_Body_0=0
Infantry_Unyielding_Body_1=Infantry_Unyielding_Body_0+20
Infantry_Unyielding_Body_2=Infantry_Unyielding_Body_1+26
Infantry_Unyielding_Body_3=Infantry_Unyielding_Body_2+36
Infantry_Unyielding_Body_4=Infantry_Unyielding_Body_3+48
Infantry_Unyielding_Body_5=Infantry_Unyielding_Body_4+64
Infantry_Unyielding_Body_6=Infantry_Unyielding_Body_5+87
Infantry_Unyielding_Body_7=Infantry_Unyielding_Body_6+116
Infantry_Unyielding_Body_8=Infantry_Unyielding_Body_7+157

Infantry_Open_Electricity_0=0
Infantry_Open_Electricity_1=Infantry_Open_Electricity_0+27
Infantry_Open_Electricity_2=Infantry_Open_Electricity_1+33
Infantry_Open_Electricity_3=Infantry_Open_Electricity_2+40
Infantry_Open_Electricity_4=Infantry_Open_Electricity_3+49
Infantry_Open_Electricity_5=Infantry_Open_Electricity_4+59
Infantry_Open_Electricity_6=Infantry_Open_Electricity_5+72
Infantry_Open_Electricity_7=Infantry_Open_Electricity_6+88
Infantry_Open_Electricity_8=Infantry_Open_Electricity_7+108
Infantry_Open_Electricity_9=Infantry_Open_Electricity_8+131
Infantry_Open_Electricity_10=Infantry_Open_Electricity_9+160
Infantry_Open_Electricity_11=Infantry_Open_Electricity_10+195
Infantry_Open_Electricity_12=Infantry_Open_Electricity_11+237

Infantry_Plasma_Shield_0=0
Infantry_Plasma_Shield_1=Infantry_Plasma_Shield_0+27
Infantry_Plasma_Shield_2=Infantry_Plasma_Shield_1+33
Infantry_Plasma_Shield_3=Infantry_Plasma_Shield_2+40
Infantry_Plasma_Shield_4=Infantry_Plasma_Shield_3+49
Infantry_Plasma_Shield_5=Infantry_Plasma_Shield_4+59
Infantry_Plasma_Shield_6=Infantry_Plasma_Shield_5+72
Infantry_Plasma_Shield_7=Infantry_Plasma_Shield_6+88
Infantry_Plasma_Shield_8=Infantry_Plasma_Shield_7+108
Infantry_Plasma_Shield_9=Infantry_Plasma_Shield_8+131
Infantry_Plasma_Shield_10=Infantry_Plasma_Shield_9+160
Infantry_Plasma_Shield_11=Infantry_Plasma_Shield_10+195
Infantry_Plasma_Shield_12=Infantry_Plasma_Shield_11+237

Infantry_Rally_Capacity_0=0
Infantry_Rally_Capacity_1=Infantry_Rally_Capacity_0+33
Infantry_Rally_Capacity_2=Infantry_Rally_Capacity_1+40
Infantry_Rally_Capacity_3=Infantry_Rally_Capacity_2+49
Infantry_Rally_Capacity_4=Infantry_Rally_Capacity_3+60
Infantry_Rally_Capacity_5=Infantry_Rally_Capacity_4+73
Infantry_Rally_Capacity_6=Infantry_Rally_Capacity_5+89
Infantry_Rally_Capacity_7=Infantry_Rally_Capacity_6+109
Infantry_Rally_Capacity_8=Infantry_Rally_Capacity_7+132
Infantry_Rally_Capacity_9=Infantry_Rally_Capacity_8+161
Infantry_Rally_Capacity_10=Infantry_Rally_Capacity_9+197
Infantry_Rally_Capacity_11=Infantry_Rally_Capacity_10+240
Infantry_Rally_Capacity_12=Infantry_Rally_Capacity_11+292

Infantry_Pulse_Elites_0=0
Infantry_Pulse_Elites_1=1118

# Hunters
Hunter_Strategic_Dispatch_0=0
Hunter_Strategic_Dispatch_1=Hunter_Strategic_Dispatch_0+8
Hunter_Strategic_Dispatch_2=Hunter_Strategic_Dispatch_1+12
Hunter_Strategic_Dispatch_3=Hunter_Strategic_Dispatch_2+20
Hunter_Strategic_Dispatch_4=Hunter_Strategic_Dispatch_3+32
Hunter_Strategic_Dispatch_5=Hunter_Strategic_Dispatch_4+51

Hunter_Ionization_Suit_0=0
Hunter_Ionization_Suit_1=Hunter_Ionization_Suit_0+20
Hunter_Ionization_Suit_2=Hunter_Ionization_Suit_1+26
Hunter_Ionization_Suit_3=Hunter_Ionization_Suit_2+36
Hunter_Ionization_Suit_4=Hunter_Ionization_Suit_3+48
Hunter_Ionization_Suit_5=Hunter_Ionization_Suit_4+64
Hunter_Ionization_Suit_6=Hunter_Ionization_Suit_5+87
Hunter_Ionization_Suit_7=Hunter_Ionization_Suit_6+116
Hunter_Ionization_Suit_8=Hunter_Ionization_Suit_7+157

Hunter_Laser_Sight_0=0
Hunter_Laser_Sight_1=Hunter_Laser_Sight_0+20
Hunter_Laser_Sight_2=Hunter_Laser_Sight_1+26
Hunter_Laser_Sight_3=Hunter_Laser_Sight_2+36
Hunter_Laser_Sight_4=Hunter_Laser_Sight_3+48
Hunter_Laser_Sight_5=Hunter_Laser_Sight_4+64
Hunter_Laser_Sight_6=Hunter_Laser_Sight_5+87
Hunter_Laser_Sight_7=Hunter_Laser_Sight_6+116
Hunter_Laser_Sight_8=Hunter_Laser_Sight_7+157

Hunter_Ionization_Shield_0=0
Hunter_Ionization_Shield_1=Hunter_Ionization_Shield_0+27
Hunter_Ionization_Shield_2=Hunter_Ionization_Shield_1+33
Hunter_Ionization_Shield_3=Hunter_Ionization_Shield_2+40
Hunter_Ionization_Shield_4=Hunter_Ionization_Shield_3+49
Hunter_Ionization_Shield_5=Hunter_Ionization_Shield_4+59
Hunter_Ionization_Shield_6=Hunter_Ionization_Shield_5+72
Hunter_Ionization_Shield_7=Hunter_Ionization_Shield_6+88
Hunter_Ionization_Shield_8=Hunter_Ionization_Shield_7+108
Hunter_Ionization_Shield_9=Hunter_Ionization_Shield_8+131
Hunter_Ionization_Shield_10=Hunter_Ionization_Shield_9+160
Hunter_Ionization_Shield_11=Hunter_Ionization_Shield_10+195
Hunter_Ionization_Shield_12=Hunter_Ionization_Shield_11+237

Hunter_Laser_Shoot_0=0
Hunter_Laser_Shoot_1=Hunter_Laser_Shoot_0+27
Hunter_Laser_Shoot_2=Hunter_Laser_Shoot_1+33
Hunter_Laser_Shoot_3=Hunter_Laser_Shoot_2+40
Hunter_Laser_Shoot_4=Hunter_Laser_Shoot_3+49
Hunter_Laser_Shoot_5=Hunter_Laser_Shoot_4+59
Hunter_Laser_Shoot_6=Hunter_Laser_Shoot_5+72
Hunter_Laser_Shoot_7=Hunter_Laser_Shoot_6+88
Hunter_Laser_Shoot_8=Hunter_Laser_Shoot_7+108
Hunter_Laser_Shoot_9=Hunter_Laser_Shoot_8+131
Hunter_Laser_Shoot_10=Hunter_Laser_Shoot_9+160
Hunter_Laser_Shoot_11=Hunter_Laser_Shoot_10+195
Hunter_Laser_Shoot_12=Hunter_Laser_Shoot_11+237

Hunter_Rally_Capacity_0=0
Hunter_Rally_Capacity_1=Hunter_Rally_Capacity_0+33
Hunter_Rally_Capacity_2=Hunter_Rally_Capacity_1+40
Hunter_Rally_Capacity_3=Hunter_Rally_Capacity_2+49
Hunter_Rally_Capacity_4=Hunter_Rally_Capacity_3+60
Hunter_Rally_Capacity_5=Hunter_Rally_Capacity_4+73
Hunter_Rally_Capacity_6=Hunter_Rally_Capacity_5+89
Hunter_Rally_Capacity_7=Hunter_Rally_Capacity_6+109
Hunter_Rally_Capacity_8=Hunter_Rally_Capacity_7+132
Hunter_Rally_Capacity_9=Hunter_Rally_Capacity_8+161
Hunter_Rally_Capacity_10=Hunter_Rally_Capacity_9+197
Hunter_Rally_Capacity_11=Hunter_Rally_Capacity_10+240
Hunter_Rally_Capacity_12=Hunter_Rally_Capacity_11+292

Hunter_Pulse_Assassins_0=0
Hunter_Pulse_Assassins_1=1118

# Riders
Rider_Strategic_Dispatch_0=0
Rider_Strategic_Dispatch_1=Rider_Strategic_Dispatch_0+8
Rider_Strategic_Dispatch_2=Rider_Strategic_Dispatch_1+12
Rider_Strategic_Dispatch_3=Rider_Strategic_Dispatch_2+20
Rider_Strategic_Dispatch_4=Rider_Strategic_Dispatch_3+32
Rider_Strategic_Dispatch_5=Rider_Strategic_Dispatch_4+51

Rider_Electric_Shock_0=0
Rider_Electric_Shock_1=Rider_Electric_Shock_0+20
Rider_Electric_Shock_2=Rider_Electric_Shock_1+26
Rider_Electric_Shock_3=Rider_Electric_Shock_2+36
Rider_Electric_Shock_4=Rider_Electric_Shock_3+48
Rider_Electric_Shock_5=Rider_Electric_Shock_4+64
Rider_Electric_Shock_6=Rider_Electric_Shock_5+87
Rider_Electric_Shock_7=Rider_Electric_Shock_6+116
Rider_Electric_Shock_8=Rider_Electric_Shock_7+157

Rider_Power_Upgrade_0=0
Rider_Power_Upgrade_1=Rider_Power_Upgrade_0+20
Rider_Power_Upgrade_2=Rider_Power_Upgrade_1+26
Rider_Power_Upgrade_3=Rider_Power_Upgrade_2+36
Rider_Power_Upgrade_4=Rider_Power_Upgrade_3+48
Rider_Power_Upgrade_5=Rider_Power_Upgrade_4+64
Rider_Power_Upgrade_6=Rider_Power_Upgrade_5+87
Rider_Power_Upgrade_7=Rider_Power_Upgrade_6+116
Rider_Power_Upgrade_8=Rider_Power_Upgrade_7+157

Rider_Electric_Shot_0=0
Rider_Electric_Shot_1=Rider_Electric_Shot_0+27
Rider_Electric_Shot_2=Rider_Electric_Shot_1+33
Rider_Electric_Shot_3=Rider_Electric_Shot_2+40
Rider_Electric_Shot_4=Rider_Electric_Shot_3+49
Rider_Electric_Shot_5=Rider_Electric_Shot_4+59
Rider_Electric_Shot_6=Rider_Electric_Shot_5+72
Rider_Electric_Shot_7=Rider_Electric_Shot_6+88
Rider_Electric_Shot_8=Rider_Electric_Shot_7+108
Rider_Electric_Shot_9=Rider_Electric_Shot_8+131
Rider_Electric_Shot_10=Rider_Electric_Shot_9+160
Rider_Electric_Shot_11=Rider_Electric_Shot_10+195
Rider_Electric_Shot_12=Rider_Electric_Shot_11+237

Rider_Power_Barrier_0=0
Rider_Power_Barrier_1=Rider_Power_Barrier_0+27
Rider_Power_Barrier_2=Rider_Power_Barrier_1+33
Rider_Power_Barrier_3=Rider_Power_Barrier_2+40
Rider_Power_Barrier_4=Rider_Power_Barrier_3+49
Rider_Power_Barrier_5=Rider_Power_Barrier_4+59
Rider_Power_Barrier_6=Rider_Power_Barrier_5+72
Rider_Power_Barrier_7=Rider_Power_Barrier_6+88
Rider_Power_Barrier_8=Rider_Power_Barrier_7+108
Rider_Power_Barrier_9=Rider_Power_Barrier_8+131
Rider_Power_Barrier_10=Rider_Power_Barrier_9+160
Rider_Power_Barrier_11=Rider_Power_Barrier_10+195
Rider_Power_Barrier_12=Rider_Power_Barrier_11+237

Rider_Rally_Capacity_0=0
Rider_Rally_Capacity_1=Rider_Rally_Capacity_0+33
Rider_Rally_Capacity_2=Rider_Rally_Capacity_1+40
Rider_Rally_Capacity_3=Rider_Rally_Capacity_2+49
Rider_Rally_Capacity_4=Rider_Rally_Capacity_3+60
Rider_Rally_Capacity_5=Rider_Rally_Capacity_4+73
Rider_Rally_Capacity_6=Rider_Rally_Capacity_5+89
Rider_Rally_Capacity_7=Rider_Rally_Capacity_6+109
Rider_Rally_Capacity_8=Rider_Rally_Capacity_7+132
Rider_Rally_Capacity_9=Rider_Rally_Capacity_8+161
Rider_Rally_Capacity_10=Rider_Rally_Capacity_9+197
Rider_Rally_Capacity_11=Rider_Rally_Capacity_10+240
Rider_Rally_Capacity_12=Rider_Rally_Capacity_11+292

Rider_Pulse_Predator_0=0
Rider_Pulse_Predator_1=1118


#############################################################
############ Fill Out Your Building Values Below ############
#############################################################

# Plasma Headquarters Levels Completed (if finished write 5):
hq1 = 0
hq2 = 0
hq3 = 0
hq4 = 0
hq5 = 0
#----
hq6 = 0
hq7 = 0
hq8 = 0
hq9 = 0
hq10 = 0

# Plasma Hero Precinct Levels Completed (if finished write 5):
hp1 = 0
hp2 = 0
hp3 = 0
hp4 = 0
hp5 = 0
#----
hp6 = 0
hp7 = 0
hp8 = 0
hp9 = 0
hp10 = 0

# Plasma Barracks Levels Completed (if finished write 5):
pb1 = 0
pb2 = 0
pb3 = 0
pb4 = 0
pb5 = 0
#----
pb6 = 0
pb7 = 0
pb8 = 0
pb9 = 0
pb10 = 0

# Plasma Range Levels Completed (if finished write 5):
pr1 = 0
pr2 = 0
pr3 = 0
pr4 = 0
pr5 = 0
#----
pr6 = 0
pr7 = 0
pr8 = 0
pr9 = 0
pr10 = 0

# Plasma Garage Levels Completed (if finished write 5):
pg1 = 0
pg2 = 0
pg3 = 0
pg4 = 0
pg5 = 0
#----
pg6 = 0
pg7 = 0
pg8 = 0
pg9 = 0
pg10 = 0

# Institute of Plasma Levels Completed (if finished write 5):
ip1 = 0
ip2 = 0
ip3 = 0
ip4 = 0
ip5 = 0
#----
ip6 = 0
ip7 = 0
ip8 = 0
ip9 = 0
ip10 = 0


#############################################################
############ Fill Out Your Research Values Below ############
#############################################################

# This section will work a little bit different due to each upgrade level requiring a different amount of plasma to complete.
# Simply write down which upgrade level you have for each node (eg. Infantry_Unyielding_Body_3 for 3/8 upgrades completed in the "Unyielding Body" node within the "Infantry" branch of the "Institute of Plasma")

#Infantry (replace the 0 with whatever upgrade level you have reached within a certain node)
i1 = Infantry_Strategic_Dispatch_0
i2 = Infantry_Powerful_Slash_0
i3 = Infantry_Unyielding_Body_0
i4 = Infantry_Open_Electricity_0
i5 = Infantry_Plasma_Shield_0
i6 = Infantry_Rally_Capacity_0
i7 = Infantry_Pulse_Elites_0

# Hunters (replace the 0 with whatever upgrade level you have reached within a certain node)
h1 = Hunter_Strategic_Dispatch_0
h2 = Hunter_Ionization_Suit_0
h3 = Hunter_Laser_Sight_0
h4 = Hunter_Ionization_Shield_0
h5 = Hunter_Laser_Shoot_0
h6 = Hunter_Rally_Capacity_0
h7 = Hunter_Pulse_Assassins_0

# Riders (replace the 0 with whatever upgrade level you have reached within a certain node)
r1 = Rider_Strategic_Dispatch_0
r2 = Rider_Electric_Shock_0
r3 = Rider_Power_Upgrade_0
r4 = Rider_Electric_Shot_0
r5 = Rider_Power_Barrier_0
r6 = Rider_Rally_Capacity_0
r7 = Rider_Pulse_Predator_0


#############################################################
######################## Actual Code ########################
########### DON'T CHANGE ANYTHING IN THIS SECTION ###########
#############################################################

# Math - Total Plasma Cost Per Building
Δphqc=(hq1c*5)+(hq2c*5)+(hq3c*5)+(hq4c*5)+(hq5c*5)+(hq6c*5)+(hq7c*5)+(hq8c*5)+(hq9c*5)+(hq10c*5)
Δphpc=(hp1c*5)+(hp2c*5)+(hp3c*5)+(hp4c*5)+(hp5c*5)+(hp6c*5)+(hp7c*5)+(hp8c*5)+(hp9c*5)+(hp10c*5)
Δpbc=(pb1c*5)+(pb2c*5)+(pb3c*5)+(pb4c*5)+(pb5c*5)+(pb6c*5)+(pb7c*5)+(pb8c*5)+(pb9c*5)+(pb10c*5)
Δprc=(pr1c*5)+(pr2c*5)+(pr3c*5)+(pr4c*5)+(pr5c*5)+(pr6c*5)+(pr7c*5)+(pr8c*5)+(pr9c*5)+(pr10c*5)
Δpgc=(pg1c*5)+(pg2c*5)+(pg3c*5)+(pg4c*5)+(pg5c*5)+(pg6c*5)+(pg7c*5)+(pg8c*5)+(pg9c*5)+(pg10c*5)
Δipc=(ip1c*5)+(ip2c*5)+(ip3c*5)+(ip4c*5)+(ip5c*5)+(ip6c*5)+(ip7c*5)+(ip8c*5)+(ip9c*5)+(ip10c*5)

# Math - Total Plasma Spent Per Building
Δphqs=(hq1c*hq1)+(hq2c*hq2)+(hq3c*hq3)+(hq4c*hq4)+(hq5c*hq5)+(hq6c*hq6)+(hq7c*hq7)+(hq8c*hq8)+(hq9c*hq9)+(hq10c*hq10)
Δphps=(hp1c*hp1)+(hp2c*hp2)+(hp3c*hp3)+(hp4c*hp4)+(hp5c*hp5)+(hp6c*hp6)+(hp7c*hp7)+(hp8c*hp8)+(hp9c*hp9)+(hp10c*hp10)
Δpbs=(pb1c*pb1)+(pb2c*pb2)+(pb3c*pb3)+(pb4c*pb4)+(pb5c*pb5)+(pb6c*pb6)+(pb7c*pb7)+(pb8c*pb8)+(pb9c*pb9)+(pb10c*pb10)
Δprs=(pr1c*pr1)+(pr2c*pr2)+(pr3c*pr3)+(pr4c*pr4)+(pr5c*pr5)+(pr6c*pr6)+(pr7c*pr7)+(pr8c*pr8)+(pr9c*pr9)+(pr10c*pr10)
Δpgs=(pg1c*pg1)+(pg2c*pg2)+(pg3c*pg3)+(pg4c*pg4)+(pg5c*pg5)+(pg6c*pg6)+(pg7c*pg7)+(pg8c*pg8)+(pg9c*pg9)+(pg10c*pg10)
Δips=(ip1c*ip1)+(ip2c*ip2)+(ip3c*ip3)+(ip4c*ip4)+(ip5c*ip5)+(ip6c*ip6)+(ip7c*ip7)+(ip8c*ip8)+(ip9c*ip9)+(ip10c*ip10)

# Math - Final Calculations for Buildings
Δpc=Δphqc+Δphpc+Δpbc+Δprc+Δpgc+Δipc      # total plasma cost
Δps=Δphqs+Δphps+Δpbs+Δprs+Δpgs+Δips      # total plasma spent
Δpmiss=Δpc-Δps                            # total plasma missing to max

# Math - Research 
Δinf=Infantry_Strategic_Dispatch_5+Infantry_Powerful_Slash_8+Infantry_Unyielding_Body_8+Infantry_Open_Electricity_12+Infantry_Plasma_Shield_12+Infantry_Rally_Capacity_12+Infantry_Pulse_Elites_1      # total plasma cost of researching the infantry branch
Δhun=Hunter_Strategic_Dispatch_5+Hunter_Ionization_Suit_8+Hunter_Laser_Sight_8+Hunter_Ionization_Shield_12+Hunter_Laser_Shoot_12+Hunter_Rally_Capacity_12+Hunter_Pulse_Assassins_1                      # total plasma cost of researching the hunter branch
Δrid=Rider_Strategic_Dispatch_5+Rider_Electric_Shock_8+Rider_Power_Upgrade_8+Rider_Electric_Shot_12+Rider_Power_Barrier_12+Rider_Rally_Capacity_12+Rider_Pulse_Predator_1                               # total plasma cost of researching the rider branch
Δres=Δinf+Δhun+Δrid                       # total plasma research cost
resinf=i1+i2+i3+i4+i5+i6+i7                # total plasma spent on infantry branch
reshun=h1+h2+h3+h4+h5+h6+h7                # total plasma spent on hunter branch
resrid=r1+r2+r3+r4+r5+r6+r7                # total plasma spent on rider branch
restot=resinf+reshun+resrid                # total plasma spent across all branches
resmiss=Δres-restot                        # total plasma missing to max

# Math - Final Calculations for Building + Research Totals
Δcombined=Δpc+Δres                        # total plasma cost to max buildings + research
totcombined=Δps+restot                    # total plasma spent across buildings & research
totmiss=Δcombined-totcombined             # total plasma missing to max both buildings + research (this line is identical to the next one in function)
#totmiss=Δpmiss+resmiss                   # different method of calculating the line above

# Printing
print(u"\u001b[1m\u001b[4m\u001b[1m Building Plasma \u001b[0m")
print('Plasma Required To Max Buildings =',Δpc)
print('Total Plasma Spent On Buildings Thus Far=',Δps)
print('Plasma Still Required To Max Buildings =',Δpmiss)
print('')
print(u"\u001b[1m\u001b[4m\u001b[1m Research Plasma \u001b[0m")
print('Plasma Required To Max Research =',Δres)
print('Total Plasma Spent On Research =',restot)
print('Plasma StilL Required To Max Research =',resmiss)
print('')
print(u"\u001b[1m\u001b[4m\u001b[1m Overall Plasma Costs \u001b[0m")
print('Plasma Required To Max All =',Δcombined)
print('Total Plasma Spent Across All Sources =',totcombined)
print('Plasma StilL Required To Max Everything =',totmiss)


#############################################################
############## Results Should Be Printed Below ##############
#############################################################
# Out:
#  Building Plasma
# Plasma Required To Max Buildings = 16530
# Total Plasma Spent On Buildings Thus Far= 0
# Plasma Still Required To Max Buildings = 16530
#
#  Research Plasma
# Plasma Required To Max Research = 18666
# Total Plasma Spent On Research = 0
# Plasma StilL Required To Max Research = 18666
#
#  Overall Plasma Costs
# Plasma Required To Max All = 35196
# Total Plasma Spent Across All Sources = 0
# Plasma StilL Required To Max Everything = 35196
